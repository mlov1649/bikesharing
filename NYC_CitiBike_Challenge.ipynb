# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 

load_csv = "201908-citibike-tripdata.csv"
tripdata = pd.read_csv(load_csv)

# %%
# 2. Check the datatypes of your columns. 


tripdata.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.

tripdata.tripduration = pd.to_datetime(tripdata.tripduration, unit = "s")

#test_tripduration

# %%
# 4. Check the datatypes of your columns. 
tripdata.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.

tripdata.to_csv("tripdata.csv", index = False)

# %%
tripdata.sort_values("tripduration",ascending = False)
# Out:
#                tripduration                 starttime  \
# 189706  1970-02-14 03:04:26  2019-08-03 11:31:37.2370
# 385277  1970-02-08 16:18:49  2019-08-05 19:53:13.6550
# 397609  1970-02-01 07:15:49  2019-08-06 02:43:44.4590
# 667440  1970-01-30 21:56:30  2019-08-09 17:47:28.6360
# 679106  1970-01-30 20:10:32  2019-08-09 19:34:51.7360
# ...                     ...                       ...
# 1056505 1970-01-01 00:01:01  2019-08-14 18:15:06.8610
# 556942  1970-01-01 00:01:01  2019-08-08 11:44:10.9450
# 2194593 1970-01-01 00:01:01  2019-08-29 20:25:11.9000
# 2050922 1970-01-01 00:01:01  2019-08-27 21:43:15.4880
# 1571943 1970-01-01 00:01:01  2019-08-21 14:32:58.7230
#
#                          stoptime  start station id  \
# 189706   2019-09-16 14:36:03.3340             453.0
# 385277   2019-09-13 12:12:02.9690            3349.0
# 397609   2019-09-06 09:59:33.9580            3511.0
# 667440   2019-09-08 15:43:58.9520             501.0
# ...
